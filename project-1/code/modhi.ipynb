# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment
#
# Craft your problem statement here using the prompt from the README and other sources you find during your investigation.

# %% [markdown]
# For my first project, i'm going to take a look at the number of traffic accidents and driving licenses issued in Saudi Arabia. I'll seek to identify trends in the data and combine our data analysis with outside research to identify likely factors influencing the outcomes of traffic accidents in the various regions in Saudi Arabia.
# in this project , i will try to verify of increase the driving licenses and traffic accidents , and what's the region and year have the maximum numbers of driving licenses issued and the region and year have the minmum numbers of driving licenses issued and the same thing withe traffic accident which region and year have the maximum numer of accident and and i try to compare between the two datasets and explain what i notes and what we achieve frome each one and i also apply what i study in my cours .

# %% [markdown]
# ## Executive Summary
# Write an executive summary that summarizes the problem and your key findings.

# %% [markdown]
# first i have description for the datasete then i have to load and display it and detect which data need to clean then clean the corrupted data and additional features then rename the features to lower case and replace the spaces with underscore to make it easy to access and deal with it when i coding . also i create a data dictionary which contain all features and description for them then visualization the data and descripe it staticaly

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code 
driving_licenses=pd.read_csv('..\data\saudi-arabia-driving-licenses-2004-2008.csv' , sep=';')
traffic_accidents=pd.read_csv('..\data\saudi-arabia-traffic-accidents-2008.csv', sep=';')

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
driving_licenses.head(10)
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
# 5           5  (2008)              Makkah          77013n
# 6           6  (2014)             Madinah          31447n
# 7           7  (2013)             Madinah          28513n
# 8           8  (2012)             Madinah          14459n
# 9           9  (1994)             Madinah           3767n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334
# 5  21.628962766, 41.2636898334
# 6  24.927534539, 39.4918237173
# 7  24.927534539, 39.4918237173
# 8  24.927534539, 39.4918237173
# ...

# %%
traffic_accidents.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year            Region  \
# 0           0             0  (2016)            Makkah
# 1           1             1  (2016)    Eastern Region
# 2           2             2  (2016)            Tabouk
# 3           3             3  (2016)              Hail
# 4           4             4  (2016)              Hail
# 5           5             5  (2016)  Northern Boarder
# 6           6             6  (2017)             Jazan
# 7           7             7  (2017)           Al-Jouf
# 8           8             8  (2017)             Total
# 9           9             9  (2016)  Northern Boarder
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# ...

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# Answer: by Seeing to the two datasets there is some additional columns we don't need it ,
# the saudi arabia driving licenses Include: year , Administritive Area which is thea same columns with saudi arabia traffic accidents with different name , Driving Liceses and geo_point_2d these are the important columns.
# and the saudi arabia traffic accidents Include : Year , Region which is same contain with Administritive Area in saudi arabia driving licenses dataset ,Indicator ,Indicator here may be we need to convert it from long to wide  and geo_point_2d as important columns

# %% [markdown]
# by seeing to arabia driving licenses dataset I noticed that there is useful columns and some additional columns ,this dataset contains Saudi Arabia driving licenses issued by administrative area in some years ago .
# and The other dataset Traffic Accidents and Casualties dataset has some additional columns and useful columns which contains Saudi Arabia traffic accidents and casualties by Region in some years ago.

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
driving_licenses.isnull().sum()
# Out:
# Unnamed: 0              0
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %%
print('Ther are {} missing value in driving_licenses dataframe'.format(driving_licenses.isnull().sum().sum()))
driving_licenses.describe()
# Out:
# Ther are 25 missing value in driving_licenses dataframe
#        Unnamed: 0
# count  350.000000
# mean   174.500000
# std    101.180532
# min      0.000000
# 25%     87.250000
# 50%    174.500000
# 75%    261.750000
# max    349.000000

# %%
traffic_accidents.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
print('Ther are {} missing value in traffic_accidents dataframe'.format(traffic_accidents.isnull().sum().sum()))
traffic_accidents.describe()
# Out:
# Ther are 6 missing value in traffic_accidents dataframe
#        Unnamed: 0  Unnamed: 0.1
# count   84.000000     84.000000
# mean    41.500000     41.500000
# std     24.392622     24.392622
# min      0.000000      0.000000
# 25%     20.750000     20.750000
# 50%     41.500000     41.500000
# 75%     62.250000     62.250000
# max     83.000000     83.000000

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
print(' the minimum possible values for driving licenses\n' ,driving_licenses.min(), '\nthe maximum possible values driving licenses\n' ,driving_licenses.max() )
# Out:
#  the minimum possible values for driving licenses
#  Unnamed: 0                   0
# Year                    (1993)
# Administritive Area    Al-Baha
# Driving Liceses        100291n
# dtype: object
# the maximum possible values driving licenses
#  Unnamed: 0                349
# Year                   (2017)
# Administritive Area     Total
# Driving Liceses         9983n
# dtype: object

# %%
print(' the minimum possible values for traffic accidents and casualities\n' ,traffic_accidents.min(), '\nthe maximum possible values traffic accidents and casualities\n' ,traffic_accidents.max() )
# Out:
#  the minimum possible values for traffic accidents and casualities
#  Unnamed: 0                     0
# Unnamed: 0.1                   0
# Year                      (2016)
# Region                  Al-Baaha
# Indicator       No. of Accidents
# Value                      1007n
# dtype: object
# the maximum possible values traffic accidents and casualities
#  Unnamed: 0                               83
# Unnamed: 0.1                             83
# Year                                 (2017)
# Region                                Total
# Indicator       No. of Casualties - Injured
# Value                                99925n
# dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
driving_licenses.dtypes
# Out:
# Unnamed: 0              int64
# Year                   object
# Administritive Area    object
# Driving Liceses        object
# geo_point_2d           object
# dtype: object

# %%
traffic_accidents.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# if see to driving licenses features :
# the year comes with object data type which most be integer data type , the same thing with geo_point_2d featur.
# about traffic accidents and casualities :
# you can see the same thing in the year ,Value and geo_point_2d featurs comes with object data type which most be integer data type

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
print('Ther are {} missing value in traffic_accidents dataframe'.format(traffic_accidents.isnull().sum().sum()))
traffic_accidents.describe()
# Out:
# Ther are 6 missing value in traffic_accidents dataframe
#        Unnamed: 0  Unnamed: 0.1
# count   84.000000     84.000000
# mean    41.500000     41.500000
# std     24.392622     24.392622
# min      0.000000      0.000000
# 25%     20.750000     20.750000
# 50%     41.500000     41.500000
# 75%     62.250000     62.250000
# max     83.000000     83.000000

# %%
driving_licenses['Year'] = driving_licenses['Year'].map(lambda x:int(x.replace('(','').replace(')','')))
driving_licenses['Driving Liceses'] = driving_licenses['Driving Liceses'].map(lambda x: int(x.replace('n','')))
driving_licenses.dtypes
# Out:
# Unnamed: 0              int64
# Year                    int64
# Administritive Area    object
# Driving Liceses         int64
# geo_point_2d           object
# dtype: object

# %%
traffic_accidents['Year'] = traffic_accidents['Year'].map(lambda x:int(x.replace('(','').replace(')','')))
traffic_accidents['Value'] = traffic_accidents['Value'].map(lambda x: int(x.replace('n','')))
traffic_accidents.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# Year             int64
# Region          object
# Indicator       object
# Value            int64
# geo_point_2d    object
# dtype: object

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
driving_licenses[['driving_licenses_x','driving_licenses_y']] = driving_licenses.geo_point_2d.apply(lambda x: pd.Series(str(x).split(',')))
driving_licenses['driving_licenses_x']=driving_licenses['driving_licenses_x'].map(lambda x: float(x))
driving_licenses['driving_licenses_y']=driving_licenses['driving_licenses_y'].map(lambda x: float(x))
driving_licenses.head()
# Out:
#    Unnamed: 0  Year Administritive Area  Driving Liceses  \
# 0           0  2012              Makkah           143954
# 1           1  1994              Makkah            75349
# 2           2  1998              Makkah            86082
# 3           3  2004              Makkah            86636
# 4           4  2005              Makkah            65099
#
#                   geo_point_2d  driving_licenses_x  driving_licenses_y
# 0  21.628962766, 41.2636898334           21.628963            41.26369
# 1  21.628962766, 41.2636898334           21.628963            41.26369
# 2  21.628962766, 41.2636898334           21.628963            41.26369
# 3  21.628962766, 41.2636898334           21.628963            41.26369
# 4  21.628962766, 41.2636898334           21.628963            41.26369

# %%
#the 'Unnamed: 0'& 'geo_point_2d' featurs iss aditional we don't neead it
driving_licenses.drop(['Unnamed: 0','geo_point_2d'] ,axis=1 , inplace=True)
driving_licenses.head()
# Out:
#    Year Administritive Area  Driving Liceses  driving_licenses_x  \
# 0  2012              Makkah           143954           21.628963
# 1  1994              Makkah            75349           21.628963
# 2  1998              Makkah            86082           21.628963
# 3  2004              Makkah            86636           21.628963
# 4  2005              Makkah            65099           21.628963
#
#    driving_licenses_y
# 0            41.26369
# 1            41.26369
# 2            41.26369
# 3            41.26369
# 4            41.26369

# %%
driving_licenses.dtypes
# Out:
# Year                     int64
# Administritive Area     object
# Driving Liceses          int64
# driving_licenses_x     float64
# driving_licenses_y     float64
# dtype: object

# %%
traffic_accidents[['traffic_accidents_x','traffic_accidents_y']] = traffic_accidents.geo_point_2d.apply(lambda x: pd.Series(str(x).split(',')))
traffic_accidents['traffic_accidents_x']=traffic_accidents['traffic_accidents_x'].map(lambda x: float(x))
traffic_accidents['traffic_accidents_y']=traffic_accidents['traffic_accidents_y'].map(lambda x: float(x))
traffic_accidents.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year          Region  \
# 0           0             0  2016          Makkah
# 1           1             1  2016  Eastern Region
# 2           2             2  2016          Tabouk
# 3           3             3  2016            Hail
# 4           4             4  2016            Hail
#
#                      Indicator  Value                  geo_point_2d  \
# 0  No. of Casualties - Injured  12383   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299   27.400845724, 41.4406960508
# 4             No. of Accidents  10199   27.400845724, 41.4406960508
#
#    traffic_accidents_x  traffic_accidents_y
# 0            21.628963            41.263690
# 1            23.288331            50.147830
# 2            27.901655            37.259858
# 3            27.400846            41.440696
# ...

# %%
#the 'Unnamed: 0' & 'Unnamed: 0.1' featurs iss aditional we don't neead them
traffic_accidents.drop(['Unnamed: 0' ,'Unnamed: 0.1','geo_point_2d'] ,axis=1 , inplace=True)
traffic_accidents.head()
# Out:
#    Year          Region                    Indicator  Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#    traffic_accidents_x  traffic_accidents_y
# 0            21.628963            41.263690
# 1            23.288331            50.147830
# 2            27.901655            37.259858
# 3            27.400846            41.440696
# 4            27.400846            41.440696

# %%
traffic_accidents.dtypes
# Out:
# Year                     int64
# Region                  object
# Indicator               object
# Value                    int64
# traffic_accidents_x    float64
# traffic_accidents_y    float64
# dtype: object

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
driving_licenses['Administritive Area'].unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Total', 'Riyadh'], dtype=object)

# %%
driving_licenses['Administritive Area'].replace('Al-Qaseem','Al-Qassim', inplace=True)
driving_licenses['Administritive Area'].replace('Eastern','Eastern Region', inplace=True)
driving_licenses['Administritive Area'].unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qassim', 'Eastern Region', 'Assir',
#        'Tabouk', 'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Total', 'Riyadh'], dtype=object)

# %%
traffic_accidents['Region'].unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baaha', 'Riyadh', 'Madinah',
#        'Qassim', 'Najran', 'Asir'], dtype=object)

# %%
traffic_accidents['Region'].replace('Al-Baaha','Al-Baha', inplace=True)
traffic_accidents['Region'].replace('Qassim','Al-Qassim', inplace=True)
traffic_accidents['Region'].replace('Asir','Assir', inplace=True)
traffic_accidents['Region'].unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baha', 'Riyadh', 'Madinah',
#        'Al-Qassim', 'Najran', 'Assir'], dtype=object)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
driving_licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 350 non-null    int64
#  1   Administritive Area  350 non-null    object
#  2   Driving Liceses      350 non-null    int64
#  3   driving_licenses_x   325 non-null    float64
#  4   driving_licenses_y   325 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 13.8+ KB

# %%
traffic_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 84 non-null     int64
#  1   Region               84 non-null     object
#  2   Indicator            84 non-null     object
#  3   Value                84 non-null     int64
#  4   traffic_accidents_x  78 non-null     float64
#  5   traffic_accidents_y  78 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.1+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
driving_licenses.dtypes
# Out:
# Year                     int64
# Administritive Area     object
# Driving Liceses          int64
# driving_licenses_x     float64
# driving_licenses_y     float64
# dtype: object

# %%
traffic_accidents.dtypes
# Out:
# Year                     int64
# Region                  object
# Indicator               object
# Value                    int64
# traffic_accidents_x    float64
# traffic_accidents_y    float64
# dtype: object

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
driving_licenses.columns =driving_licenses.columns.str.lower().str.replace(' ','_').str.replace('administritive_area', 'region').str.replace('driving_liceses','driving_licenses')
driving_licenses.head()
# Out:
#    year  region  driving_licenses  driving_licenses_x  driving_licenses_y
# 0  2012  Makkah            143954           21.628963            41.26369
# 1  1994  Makkah             75349           21.628963            41.26369
# 2  1998  Makkah             86082           21.628963            41.26369
# 3  2004  Makkah             86636           21.628963            41.26369
# 4  2005  Makkah             65099           21.628963            41.26369

# %%
traffic_accidents.columns =  traffic_accidents.columns.str.lower().str.replace(' ','_')
traffic_accidents.head()
# Out:
#    year          region                    indicator  value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#    traffic_accidents_x  traffic_accidents_y
# 0            21.628963            41.263690
# 1            23.288331            50.147830
# 2            27.901655            37.259858
# 3            27.400846            41.440696
# 4            27.400846            41.440696

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**year**	                        | integer  |Driving_Licenses| the year of  the licenses issuance |
# |**region**                   	| object   |Driving_Licenses| the region where the licenses issuance|
# |**driving_liceses**            	| int      |Driving_Licenses| Number of Driving Licenses|
# |**y**                          	| float    |Driving_Licenses| the longitude of the region |
# |**x**                         	| float    |Driving_Licenses| latitude of the region|
# |**year**                           | int      |Traffic_Accidents| the year of traffic accidents and casualties |
# |**region**	                        | object   |Traffic_Accidents| the region wher traffic accidents and casualties |
# |**indicator**                      | object   |Traffic_Accidents| contain the description of  value featur numbers there is two description in it 'No. of Casualties - Injured' , 'No. of Casualties - Dead' and No. of Accident |
# |**value**                          | int      |Traffic_Accidents| contain the numberd which was descripted in indictor |
# |**y**                          	| float    |Traffic_Accidents| the longitude of the region |
# |**x**                         	| float    |Traffic_Accidents| latitude of the region|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
#
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
driving_licenses['region'].unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qassim', 'Eastern Region', 'Assir',
#        'Tabouk', 'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Total', 'Riyadh'], dtype=object)

# %%
driving_licenses.groupby('region')[['driving_licenses']].count()
# Out:
#                   driving_licenses
# region
# Al-Baha                         25
# Al-Jouf                         25
# Al-Qassim                       25
# Assir                           25
# Eastern Region                  25
# Hail                            25
# Jazan                           25
# Madinah                         25
# Makkah                          25
# Najran                          25
# Northern Boarder                25
# Riyadh                          25
# Tabouk                          25
# Total                           25

# %% [markdown]
# If you notice that there is 13 region and total row ,it does not belong to the names of the regions

# %%
#drop the total row
driving_licenses = driving_licenses[(driving_licenses['region'] != 'Total')]

# %%
driving_licenses['region'].unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qassim', 'Eastern Region', 'Assir',
#        'Tabouk', 'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %%
traffic_accidents['region'].unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baha', 'Riyadh', 'Madinah',
#        'Al-Qassim', 'Najran', 'Assir'], dtype=object)

# %%
traffic_accidents.groupby('region')['value'].count()
# Out:
# region
# Al-Baha             6
# Al-Jouf             6
# Al-Qassim           6
# Assir               6
# Eastern Region      6
# Hail                6
# Jazan               6
# Madinah             6
# Makkah              6
# Najran              6
# Northern Boarder    6
# Riyadh              6
# Tabouk              6
# Total               6
# Name: value, dtype: int64

# %%
#drop the total row
traffic_accidents = traffic_accidents[(traffic_accidents['region'] != 'Total')]

# %% [markdown]
# If you notice that there is 13 region and total row ,it does not belong to the names of the regions

# %%
traffic_accidents['region'].unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Al-Baha', 'Riyadh', 'Madinah', 'Al-Qassim',
#        'Najran', 'Assir'], dtype=object)

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?

# %% [markdown]
# the License data it' in a wide format which is better for me , but in Accident data there is two featurs indicator and value in  a long format i'll try to convert them into wide to be more clear and easy th deal with them

# %%
traffic_accidents.columns
# Out:
# Index(['year', 'region', 'indicator', 'value', 'traffic_accidents_x',
#        'traffic_accidents_y'],
#       dtype='object')

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
traffic_accidents=traffic_accidents.pivot(index=['year', 'region','traffic_accidents_x', 'traffic_accidents_y'], columns='indicator' , values='value').reset_index()
traffic_accidents.head()
# Out:
# indicator  year          region  traffic_accidents_x  traffic_accidents_y  \
# 0          2016         Al-Baha            20.148406            41.466548
# 1          2016         Al-Jouf            29.967745            39.557037
# 2          2016       Al-Qassim            26.196706            43.343000
# 3          2016           Assir            19.138785            42.941470
# 4          2016  Eastern Region            23.288331            50.147830
#
# indicator  No. of Accidents  No. of Casualties - Dead  \
# 0                      3618                       185
# 1                     10212                       245
# 2                     25664                       397
# 3                     32684                       983
# 4                    101619                      1113
#
# indicator  No. of Casualties - Injured
# 0                                 1227
# 1                                  920
# 2                                 1513
# ...

# %%
traffic_accidents.columns.name
# Out:
# 'indicator'

# %%
traffic_accidents.columns.name = None
traffic_accidents.head(2)
# Out:
#    year   region  traffic_accidents_x  traffic_accidents_y  No. of Accidents  \
# 0  2016  Al-Baha            20.148406            41.466548              3618
# 1  2016  Al-Jouf            29.967745            39.557037             10212
#
#    No. of Casualties - Dead  No. of Casualties - Injured
# 0                       185                         1227
# 1                       245                          920

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
combined_datasets = pd.merge(driving_licenses,traffic_accidents, on=['region' , 'year' ], how='inner')
combined_datasets.head()
# Out:
#    year            region  driving_licenses  driving_licenses_x  \
# 0  2017              Hail             22035           27.400846
# 1  2017  Northern Boarder              5280           30.197075
# 2  2016           Al-Baha              4614           20.148406
# 3  2017         Al-Qassim              6318           26.196706
# 4  2017    Eastern Region            126816           23.288331
#
#    driving_licenses_y  traffic_accidents_x  traffic_accidents_y  \
# 0           41.440696            27.400846            41.440696
# 1           41.817119            30.197075            41.817119
# 2           41.466548            20.148406            41.466548
# 3           43.343000            26.196706            43.343000
# 4           50.147830            23.288331            50.147830
#
#    No. of Accidents  No. of Casualties - Dead  No. of Casualties - Injured
# 0              9379                       265                          773
# ...

# %% [markdown]
# i chose inner join to avoid null values

# %%
combined_datasets.isnull().sum()
# Out:
# year                           0
# region                         0
# driving_licenses               0
# driving_licenses_x             0
# driving_licenses_y             0
# traffic_accidents_x            0
# traffic_accidents_y            0
# No. of Accidents               0
# No. of Casualties - Dead       0
# No. of Casualties - Injured    0
# dtype: int64

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
combined_datasets.to_csv('..\data\combined_datasets.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
combined_datasets.describe()
# Out:
#               year  driving_licenses  driving_licenses_x  driving_licenses_y  \
# count    26.000000         26.000000           26.000000           26.000000
# mean   2016.500000      62507.000000           23.810447           42.602789
# std       0.509902     107293.917762            4.274533            3.313532
# min    2016.000000       2153.000000           17.207231           37.259858
# 25%    2016.000000       8363.250000           20.148406           41.263690
# 50%    2016.500000      16085.000000           23.288331           41.817119
# 75%    2017.000000      51222.000000           27.400846           43.343000
# max    2017.000000     495307.000000           30.197075           50.147830
#
#        traffic_accidents_x  traffic_accidents_y  No. of Accidents  \
# count            26.000000            26.000000         26.000000
# mean             23.810447            42.602789      38225.692308
# std               4.274533             3.313532      46493.705035
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def mean(data):
  n = len(data)
  mean = sum(data) / n
  return mean
 
def variance(data):
  n = len(data)
  mean = sum(data) / n
  deviations = [(x - mean) ** 2 for x in data]
  variance = sum(deviations) / n
  return variance
 
def stdev(data):
  import math
  var = variance(data)
  std_dev = math.sqrt(var)
  return std_dev
   
stdev(combined_datasets['No. of Accidents'])

#46493.705035
# Out:
# 45590.82869880505

# %%
np.std(combined_datasets['No. of Accidents'])
# Out:
# 45590.82869880505

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %%
sd={i : stdev(combined_datasets[combined_datasets[i].notnull()][i]) for i in combined_datasets.columns if i != 'region' if i != 'year'}

print(sd)
# Out:
# {'driving_licenses': 105210.34237659337, 'driving_licenses_x': 4.191524025811861, 'driving_licenses_y': 3.2491853051316912, 'traffic_accidents_x': 4.191524025811861, 'traffic_accidents_y': 3.2491853051316912, 'No. of Accidents': 45590.82869880505, 'No. of Casualties - Dead': 539.1069593406002, 'No. of Casualties - Injured': 2865.885411322023}

# %%
np.std(combined_datasets['No. of Accidents'])
# Out:
# 45590.82869880505

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: it not exactly same as which describe provided but still very closer from it

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#1-Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# [(driving_licenses['year']>=1993) & (driving_licenses['year']<=2017)]
print(sorted(driving_licenses['year'].unique()))
# Out:
# [1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %% [markdown]
# by seeing to the unigue year value all the year is between 1993-2017 which mean we doesn't need to filtering the years .

# %%
#driving_licenses,traffic_accidents
print('min' ,
driving_licenses.groupby('region')['driving_licenses'].min().sort_values().head(),'\n----\n','max',driving_licenses.groupby('region')['driving_licenses'].max().sort_values().tail()
)
# Out:
# min region
# Tabouk               915
# Al-Baha              997
# Northern Boarder    1318
# Najran              1864
# Jazan               2226
# Name: driving_licenses, dtype: int64
# ----
#  max region
# Hail               54507
# Al-Qassim          73618
# Eastern Region    151087
# Makkah            157389
# Riyadh            495307
# Name: driving_licenses, dtype: int64

# %% [markdown]
# by seeing here i notes the region has the highest Driving Licenses is Riyadh and the lowest Driving Licenses is Tabouk

# %%
print(traffic_accidents.columns)
# Out:
# Index(['year', 'region', 'traffic_accidents_x', 'traffic_accidents_y',
#        'No. of Accidents', 'No. of Casualties - Dead',
#        'No. of Casualties - Injured'],
#       dtype='object')

# %% [markdown]
# the same think here we doesn't need to filtering the years

# %%
#2-Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
traffic_accidents.groupby('region')['No. of Accidents'].mean().sort_values()
# Out:
# region
# Al-Baha               2516.0
# Najran                3214.0
# Hail                  9789.0
# Al-Jouf              10340.5
# Northern Boarder     12368.0
# Tabouk               13872.0
# Madinah              15272.5
# Jazan                24017.0
# Al-Qassim            24034.5
# Assir                28964.5
# Eastern Region       91526.0
# Riyadh              120830.5
# Makkah              140189.5
# Name: No. of Accidents, dtype: float64

# %% [markdown]
# here we see the region the highest mean of traffic accidents numbers is Makkah and the region the lowest mean of traffic accidents numbers is Al-Baha

# %%
#3-What are the regions that have more Driving Licenses issued in each year than the year average
#first:calculate mean each year:
k=pd.DataFrame(driving_licenses.groupby('year')['driving_licenses'].mean().round(2)).reset_index()
k.head()
# Out:
#    year  driving_licenses
# 0  1993          22684.08
# 1  1994          23347.69
# 2  1995          19375.23
# 3  1996          18278.69
# 4  1997          22253.54

# %%
#second: no. of the driving licesnes in each region in  each year :
m = pd.DataFrame(driving_licenses.groupby(['year','region'])['driving_licenses'].mean()).reset_index()
m.head()
# Out:
#    year          region  driving_licenses
# 0  1993         Al-Baha              3270
# 1  1993         Al-Jouf              2884
# 2  1993       Al-Qassim             73618
# 3  1993           Assir              6226
# 4  1993  Eastern Region              9964

# %%
#third: join (no. of the driving licesnes in each region in  each year and the mean of each year)
dfm=m.merge(k, how='outer',left_on='year',right_on='year')
dfm.head(2)
# Out:
#    year   region  driving_licenses_x  driving_licenses_y
# 0  1993  Al-Baha                3270            22684.08
# 1  1993  Al-Jouf                2884            22684.08

# %%
#forth:comparison between yearly region driving licesnes and yearly regionally mean
from collections import Counter
comp_col= np.where((dfm["driving_licenses_x"] > dfm["driving_licenses_y"]),dfm['region'],'')
print(Counter(comp_col))
# Out:
# Counter({'': 251, 'Makkah': 25, 'Riyadh': 21, 'Eastern Region': 21, 'Al-Qassim': 5, 'Assir': 1, 'Hail': 1})

# %%
dfm_det=dfm[(dfm["driving_licenses_x"] > dfm["driving_licenses_y"])]
dfm_det.head()
# Out:
#     year     region  driving_licenses_x  driving_licenses_y
# 2   1993  Al-Qassim               73618            22684.08
# 8   1993     Makkah               65977            22684.08
# 11  1993     Riyadh              103886            22684.08
# 15  1994  Al-Qassim               68916            23347.69
# 21  1994     Makkah               75349            23347.69

# %%
#4-What are the regions that have more Traffic Accidents happened in each year than the year average
#first:calculate mean each year:
a=pd.DataFrame(traffic_accidents.groupby('year')['No. of Accidents'].mean().round(2)).reset_index()
a.head()
# Out:
#    year  No. of Accidents
# 0  2016          41029.23
# 1  2017          35422.15

# %%
#second: No. of Accidents in each region in  each year :
b = pd.DataFrame(traffic_accidents.groupby(['year','region'])['No. of Accidents'].mean()).reset_index()
b.head()
# Out:
#    year          region  No. of Accidents
# 0  2016         Al-Baha              3618
# 1  2016         Al-Jouf             10212
# 2  2016       Al-Qassim             25664
# 3  2016           Assir             32684
# 4  2016  Eastern Region            101619

# %%
#third: join (no. of the driving licesnes in each region in  each year and the mean of each year)
dfa=b.merge(a, how='outer',left_on='year',right_on='year')
dfa.head(2)
# Out:
#    year   region  No. of Accidents_x  No. of Accidents_y
# 0  2016  Al-Baha                3618            41029.23
# 1  2016  Al-Jouf               10212            41029.23

# %%
#forth:comparison between yearly region driving licesnes and yearly regionally mean
compar_col= np.where((dfa["No. of Accidents_x"] > dfa["No. of Accidents_y"]),dfa['region'],'')
print(Counter(compar_col))
# Out:
# Counter({'': 20, 'Eastern Region': 2, 'Makkah': 2, 'Riyadh': 2})

# %%
dfa_det=dfa[(dfa["No. of Accidents_x"] > dfa["No. of Accidents_y"])]
dfa_det.head()
# Out:
#     year          region  No. of Accidents_x  No. of Accidents_y
# 4   2016  Eastern Region              101619            41029.23
# 8   2016          Makkah              134838            41029.23
# 11  2016          Riyadh              141736            41029.23
# 17  2017  Eastern Region               81433            35422.15
# 21  2017          Makkah              145541            35422.15

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(16,8));
plt.xticks(rotation=-10,  horizontalalignment='center', fontsize=15)
plt.yticks(verticalalignment='center', fontsize=15)
font = {'family': 'serif', #Font;
        'color':  'Purple', #color;
        'weight': 'bold',  #weight (bold, regilar);
        'size': 14,        #Font size;
        }

ax= sns.heatmap(combined_datasets.corr() , cmap='Purples' , annot=True);
ax.set(title = 'Heatmap (combined_datasets)');

# %% [markdown]
# here we can see the relationships between all numrical columns in (combined_datasets) dataset

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2 , figsize=(16,8)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column] )# feel free to add more settings
        
        ax[i].set_xlabel(list_of_xlabels[i])# Set titles, labels, etc here for each subplot
    return plt.tight_layout()

# %%
combined_datasets.columns
# Out:
# Index(['year', 'region', 'driving_licenses', 'driving_licenses_x',
#        'driving_licenses_y', 'traffic_accidents_x', 'traffic_accidents_y',
#        'No. of Accidents', 'No. of Casualties - Dead',
#        'No. of Casualties - Injured'],
#       dtype='object')

# %%
subplot_histograms(combined_datasets,['No. of Casualties - Dead','No. of Casualties - Injured'],['No. of Casualties - Dead','No. of Casualties - Injured'],['No. of Casualties - Dead','No. of Casualties - Injured'])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
fig, axes = plt.subplots(nrows=1, ncols=2 ,figsize=(16,8));

combined_datasets['driving_licenses'].plot(kind='hist',ax=axes[0],color='m');
axes[0].set_title('driving_licenses');
combined_datasets['No. of Accidents'].plot( kind='hist',ax=axes[1], color='y');
axes[1].set_title('No. of Accidents');

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
fig, axes = plt.subplots(2,2, figsize=(20,14))
combined_datasets[combined_datasets['year'] == 2017].plot(kind='scatter', x='driving_licenses', y='No. of Accidents', marker='^',c='red' ,alpha=0.6, ax=axes[0][0], title='Driving Licenses vs. Traffic Accidents for 2017');
combined_datasets[combined_datasets['year'] == 2016].plot(kind='scatter', x='driving_licenses', y='No. of Accidents',marker='*',c='y' , ax=axes[0][1] , title = 'Driving Licenses vs. Traffic Accidents for 2016');
combined_datasets.plot(kind='scatter', x='year', y='driving_licenses',c='b', ax=axes[1][0] , title='Driving Licenses for 2016 vs 2017');
combined_datasets.plot(kind='scatter', x='year', y='No. of Accidents', marker='+',c='grey', ax=axes[1][1] ,title= 'Traffic Accidents for 2016 vs 2017');

# %% [markdown]
# - let we bign with 'Driving Licenses vs. Traffic Accidents for 2017' plot here we can see the most valuom when no. of accidents between 0-30000 and the driving liceses between 0-50000 and some aditional hidhest outliers
# - then let we see 'Driving Licenses vs. Traffic Accidents for 2016' plot we  can see here most of data located between 0-30000
#          * i can say  no. of accidents and driving liceses driving liceses
# - be seeing to the years i can see the driving liceses It increases with time and i think 2017 has highest outlier
# - the same thing with no. of accidents it inceases with time but all of years may have outliers

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
def var_standardized(var):
    var_stand = (var-var.mean())/var.std()
    return var_stand

combined_datasets_stand = var_standardized(combined_datasets)
fig,ax=plt.subplots(figsize=(16,8))

sns.boxplot(data=combined_datasets_stand, orient='h', fliersize=5, 
                 linewidth=3, notch=True, saturation=0.5, ax=ax)
plt.title('This plot is from standardized data frame');

# %%
fig, axes = plt.subplots(2,2, figsize=(20,14));
combined_datasets[['driving_licenses']].boxplot( ax=axes[0][0])
axes[0][0].set_title('driving_licenses')
combined_datasets[['No. of Accidents']].boxplot( ax=axes[0][1])
axes[0][1].set_title('No. of Accidents')
combined_datasets[['No. of Casualties - Dead']].boxplot( ax=axes[1][0])
axes[1][0].set_title ('No. of Casualties - Dead' )
combined_datasets[['No. of Casualties - Injured']].boxplot( ax=axes[1][1])
axes[1][1].set_title ( 'No. of Casualties - Injured')
# Out:
# Text(0.5, 1.0, 'No. of Casualties - Injured')

# %% [markdown]
# let we take one be one :
#  1. driving liceses : right skewed with 5 highest outliers.
#  2. number of accidents : right skewesd with 6 highest outliers.
#  3. number of casualites 'Dead' : right skewed with 1 highest outliers.
#  4. number of casualites 'Injured' : right skewed with 1 highest outliers.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
combined_datasets.plot(x='region',y='No. of Accidents', kind='scatter', c='grey', colormap='Greys', figsize=(24,8));

# %% [markdown]
# here we can see Makkah and Riyadh have the biggest no. of accidents which greater than 140000 accidents. and most of region smaller than 40000 . becaues Makkah and Riyadh have big numbers of cars .

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']].mean()
# Out:
# driving_licenses               62507.000000
# No. of Accidents               38225.692308
# No. of Casualties - Dead         635.384615
# No. of Casualties - Injured     2743.038462
# dtype: float64

# %%
combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']].median()
# Out:
# driving_licenses               16085.0
# No. of Accidents               16050.5
# No. of Casualties - Dead         415.5
# No. of Casualties - Injured     1618.5
# dtype: float64

# %%
stats.mode(combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']])[0][0]
# Out:
# array([2153, 1414,  112,  374], dtype=int64)

# %%
stats.skew(combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']])
# Out:
# array([2.84788062, 1.3993056 , 1.32362381, 2.16771345])

# %% [markdown]
# Answers:
# 1. driving_liceses mean : 62507.000000 , median :16085.0 , mode :2153 , the distribution is positively skewed
# 2. No. of Accidents mean : 38225.692308 , median : 16050.5 , mode :  1414 , the distribution is positively skewed
# 3. No. of Casualties - Dead mean: 635.384615 , median : 415.5 mode : 112 , the distribution is positively skewed
# 4. No. of Casualties - Injured mean : 2743.038462 , median : 1618.5 , mode : 374 , the distribution is positively skewed

# %%
combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']].var()
# Out:
# driving_licenses               1.151198e+10
# No. of Accidents               2.161665e+09
# No. of Casualties - Dead       3.022618e+05
# No. of Casualties - Injured    8.541831e+06
# dtype: float64

# %%
np.std(np.ptp(combined_datasets[['driving_licenses','No. of Accidents','No. of Casualties - Dead' , 'No. of Casualties - Injured']]))
# Out:
# 0.0

# %% [markdown]
# i don't know why the standerd diviation is 0 here but may be because i standrize it in the up for drop box plot

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: yes

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:yes

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:   https://modhi-almannaa.blogspot.com/2020/12/accidents-definition-of-traffic.html

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:
# by analyzing the data i notes that evrey year the number of Driving Licenses issued are increase especially in the big cityes which make the number of car accidents is increasing also . I suggest placing more surveillance cameras and increasing the value of fines to deter violators of the regulations and impose more penalties on them and increase traffic signals at intersections to regulate traffic and distribute the start and end times of the employees to reduce traffic congestion
